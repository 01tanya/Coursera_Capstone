# %%
import random # library for random number generation
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes
import requests
from sklearn.cluster import KMeans
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Creating the same dataframe as in the previous notebook

# %%
url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}
r = requests.get(url, headers=header)
tables = pd.read_html(r.text)
df1=pd.DataFrame(tables[0])
df1.columns=['Postcode','Borough','Neighbourhood']
df1.drop([0],axis=0,inplace=True)
df1.drop(df1.loc[df1['Borough']== 'Not assigned'].index, axis = 0, inplace=True)
df1 = df1.groupby(by='Postcode',sort = False).agg({'Borough': 'first', 'Neighbourhood': ', '.join}).reset_index()
df1.loc[df1['Neighbourhood']=="Not assigned",'Neighbourhood']=df1.loc[df1['Neighbourhood']=="Not assigned",'Borough']

# %% [markdown]
# ## Adding longitude and latitude values
#
# ### Now that you have built a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name, in order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood.
# ### We will use a link to a csv file that has the geographical coordinates of each postal code: http://cocl.us/Geospatial_data to get the latitude and the longitude coordinates of each neighborhood.
#
# #### I am using IBM Watson studio and added the file as a data asset and now fetching the table

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# @client_53416b9db1b741d6aad479f9e3d76df4 = ibm_boto3.client(service_name='s3',
# @ibm_api_key_id='5Rdxv-EekCRm8n8WYdmwfP-NthPnDUR3sTdV_Urv8E1Y',
# @ibm_auth_endpoint="https://iam.bluemix.net/oidc/token",
# @config=Config(signature_version='oauth'),
# @endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com'

body = client_53416b9db1b741d6aad479f9e3d76df4.get_object(Bucket='capstone-donotdelete-pr-ajwuhdpthlv4jt',Key='Geospatial_Coordinates.csv')['Body']

if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body ) 

df2 = pd.read_csv(body)
df2.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ## Joining the dataframes and displaying some rows

# %%
df1 = df1.join(df2)
df1.head(11)
# Out:
#    Postcode                     Neighbourhood           Borough Postal Code  \
# 0       M3A                         Parkwoods        North York         M1B
# 1       M4A                  Victoria Village        North York         M1C
# 2       M5A         Harbourfront, Regent Park  Downtown Toronto         M1E
# 3       M6A  Lawrence Heights, Lawrence Manor        North York         M1G
# 4       M7A                      Queen's Park      Queen's Park         M1H
# 5       M9A                  Islington Avenue         Etobicoke         M1J
# 6       M1B                    Rouge, Malvern       Scarborough         M1K
# 7       M3B                   Don Mills North        North York         M1L
# 8       M4B   Woodbine Gardens, Parkview Hill         East York         M1M
# 9       M5B          Ryerson, Garden District  Downtown Toronto         M1N
# 10      M6B                         Glencairn        North York         M1P
#
#      Latitude  Longitude
# 0   43.806686 -79.194353
# ...
